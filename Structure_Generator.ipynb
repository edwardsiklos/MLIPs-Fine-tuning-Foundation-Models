# %%
#----- RANDOM STRUCTURE GENERATOR -----
# 1. Generates random carbon structures
# 2. Writes them into ase structure files in Random_Structures

# --- INPUTS ---
# Structure Parameters
generate_all_defaults = False # 64 and 216 random carbon structures between 1.25 and 3.5 gcm at 0.25 gcm intervals

# Manually set params if desired
set_number_of_atoms = 3
set_density_g_cm_3 = 2
set_minimum_interatomic_distance = 1.75
set_atomic_number = 6
set_atomic_mass = 12.001

# Random Seed
import numpy as np
rng = np.random.default_rng(1) 

# --- STRUCTURE GENERATOR ---
import ase 
from ase.io import write
from pathlib import Path

# Structure Generator
def random_cell_generator(number_of_atoms, density_g_cm_3, minimum_interatomic_distance, atomic_number, atomic_mass, rng):
    
    # Density calculator - ASE uses Angstrom
    number_density = density_g_cm_3 / atomic_mass * 6.022 * 10 ** 23 / (10**24)

    # Cell Properties
    cell_volume = number_of_atoms / number_density
    cell_length = cell_volume ** (1/3)
    cell = np.full(3, cell_length)

    # Identity and position of atoms
    numbers = np.full(number_of_atoms, atomic_number)
    positions = []
    
    data_dir = Path(f"Random_Structures")
    data_dir.mkdir(exist_ok=True)

    # Files are sorted into by atom-number directories
    num_atom_dir = data_dir / f"{number_of_atoms}_atoms"
    num_atom_dir.mkdir(parents = True, exist_ok=True)

    filename = (
    f"{density_g_cm_3:.2f}_gcm"
    )

    file_path = num_atom_dir / filename

    # Check if structure already exists
    if file_path.exists():
        return None
    
    # Sanity Check on density
    mean_separation = (1 / number_density) ** (1/3)
    if minimum_interatomic_distance > 0.99*mean_separation:
        return(print(f"FAILED: Mininum distance too close to mean separation of {mean_separation}"))
    if minimum_interatomic_distance > 0.98*mean_separation:
        print(f"WARNING - SLOW:Minimum distance approaching mean separation of {mean_separation}")
    
    # Rejection Sampling used to generate random positions
    while len(positions) < number_of_atoms:   
        new_atom = rng.random(3) * cell_length
        if len(positions) == 0:
                nearest_neighbour = np.inf
        else:  
            pos_array = np.array(positions)
            vector_diffs = pos_array - new_atom
            scalar_diffs = np.linalg.norm(vector_diffs, axis=1)
            nearest_neighbour = min(scalar_diffs)
        if nearest_neighbour > minimum_interatomic_distance:
            positions.append(new_atom)
            
    # Final Structure
    structure = ase.Atoms(
        numbers=numbers,
        positions=positions,
        cell=cell,
        pbc=True
    )

    write(
        file_path,
        structure,
        format="lammps-data",
        atom_style="atomic" 
    )
    return file_path


if generate_all_defaults:
    number_of_atoms =[64, 216]
    minimum_interatomic_distance = 1.75
    atomic_number = 6
    atomic_mass = 12.011
    for num_atoms in number_of_atoms:
        for density_g_cm_3 in np.arange (1.25,3.6,0.25):
            new_file = random_cell_generator(num_atoms, density_g_cm_3, 
                                            minimum_interatomic_distance, atomic_number, 
                                            atomic_mass, rng )
            if new_file is None:
                continue 
            print(f"{new_file} created")
else:
    new_file = random_cell_generator(set_number_of_atoms, set_density_g_cm_3, 
                          set_minimum_interatomic_distance, set_atomic_number, 
                          set_atomic_mass, rng )
    print(f"{new_file} created")

# %%
# Nanotube Generator
from ase.build import nanotube

# Note: energy results from length=1 are the same as length=5 within 4 sig figs
# length=5 comes with much higher compute time
ase_nanotube_9_9 = nanotube(9, 9, length=10, vacuum=20.0) 
ase_nanotube_9_9.set_pbc([True, True, True])            
ase_nanotube_9_9.write("ase_nanotube_9_9_10.cif")

ase_nanotube_9_0 = nanotube(9, 0, length=10, vacuum=20.0) 
ase_nanotube_9_0.set_pbc([True, True, True])            
ase_nanotube_9_0.write("ase_nanotube_9_0_10.cif")

# %%
# File converter
from ase.io import read, write
from pathlib import Path

for file in Path("GAP_20_dataset/structures").rglob('*'):
    if file.suffix != '.cif':
        continue
    atoms = read(file)
    write(f"Carbon_Structures/Crystalline/Downloaded/{file.stem}.cif", atoms)

# %%
# Structure Visualiser

from ase.visualize import view
from ase.io import read

atoms = read("GAP_20_dataset/Nanotube_9_9_GAP_20")
view(atoms, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 44.40728938">
#     <group/>
#   </viewpoint>
#   <transform translation="-11.101822345 -11.101822345 -1.23510739">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 22.20364469 0.0 0.0 22.20364469 22.20364469 0.0 0.0 22.20364469 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 2.47021478">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 22.20364469 0.0 0.0 22.20364469 22.20364469 0.0 0.0 22.20364469 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 22.20364469 0.0 0.0 22.20364469 0.0 2.47021478 0.0 0.0 2.47021478 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 22.20364469 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 22.20364469 0.0 0.0 22.20364469 0.0 2.47021478 0.0 0.0 2.47021478 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="5.0017371 11.81452404 1.85384254">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="17.19988927 10.3902788 0.61783856">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="16.22848892 7.73059967 0.61771962">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="14.76410815 6.18083124 1.85643752">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="13.53228791 5.46427322 1.8505265">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="15.31458402 6.64079039 0.62050118">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="12.86013008 5.21716863 0.61865862">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="16.59085307 8.34837212 1.85021589">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="10.73970177 4.96907155 1.84781433">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="11.45998068 4.97148908 0.62159736">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="8.67187168 5.46044797 0.62109816">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="6.89038623 6.63414196 1.85389733">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.97153391 7.73062543 1.85027592">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="7.4372913 6.1788298 0.61736687">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.61827126 8.34542548 0.61573737">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="9.33689682 5.21754743 1.84811307">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="17.07963989 9.68739134 1.85123313">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="17.19741867 11.81665692 0.61357376">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="16.23381269 14.47066923 0.62212801">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.13233495 12.52070651 0.61755162">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="5.97535271 14.47651345 1.85304913">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="6.88812212 15.56864034 1.85560227">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appea

# %%
from ase.build import nanotube
from ase.visualize import view
from ase.io import read


view(atoms, viewer='x3d')
ase_nanotube = nanotube(9, 0, length=1, vacuum=20.0) 
ase_nanotube.set_pbc([True, True, True])
view(ase_nanotube, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 94.091966566981">
#     <group/>
#   </viewpoint>
#   <transform translation="-23.52299164174525 -23.469469482587932 -2.13">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 47.0459832834905 0.0 0.0 47.0459832834905 46.938938965175865 0.0 0.0 46.938938965175865 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 4.26">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 47.0459832834905 0.0 0.0 47.0459832834905 46.938938965175865 0.0 0.0 46.938938965175865 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 47.0459832834905 0.0 0.0 47.0459832834905 0.0 4.26 0.0 0.0 4.26 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 46.938938965175865 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 47.0459832834905 0.0 0.0 47.0459832834905 0.0 4.26 0.0 0.0 4.26 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="27.0459832834905 23.469469482587932 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="26.833520890583696 24.674403588832774 3.55">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="26.833520890583696 24.674403588832774 2.13">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="26.221759812058806 25.73400485893102 1.42">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="26.221759812058806 25.73400485893102 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="25.284487462617875 26.520469741659568 3.55">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="25.284487462617875 26.520469741659564 2.1300000000000003">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="24.13475272027014 26.93893896517586 1.4200000000000004">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="24.13475272027014 26.93893896517586 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="22.91123056322036 26.93893896517586 3.549999999999999">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="22.91123056322036 26.93893896517586 2.1299999999999994">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="21.761495820872625 26.520469741659564 1.4199999999999995">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="21.761495820872625 26.520469741659568 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.824223471431694 25.73400485893102 3.5500000000000007">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.824223471431694 25.73400485893102 2.1299999999999994">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.212462392906804 24.674403588832778 1.4199999999999995">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.212462392906804 24.674403588832778 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.0 23.469469482587932 3.5500000000000007">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.0 23.469469482587932 2.1299999999999994">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.212462392906804 22.26453537634309 1.4199999999999995">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="20.212462392906804 22.26453537634309 0.0">
#           <shape>
#             <appearan
